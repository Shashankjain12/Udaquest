# %% [markdown]
# <h1><center> PANDAS  </center></h1>
# <h2> Day 17 </h2>
# <img src="./images/day17_1.PNG"></img>

# %%
import pandas as pd
df=pd.read_csv("./Automobile_data.csv")

# %%
# 1
df.head(n=5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail(n=5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# <img src="./images/day17_2.PNG"></img>

# %%
#2
import numpy as np
df.replace(to_replace='?' or 'n.a',value=np.NaN,inplace=True)

# %%
df.to_csv("Automobile_data.csv")

# %% [markdown]
# <img src="./images/day17_3.PNG"></img>

# %%
#3
df[df['price']==max(df['price'])][['company','price']]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# <img src="./images/day17_4.PNG"></img>

# %%
#4
df[df['company']=='toyota'][:]
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %% [markdown]
# <img src="./images/day17_5.PNG"></img>

# %%
# 5
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mitsubishi       4
# mercedes-benz    4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# jaguar           3
# porsche          3
# isuzu            3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %% [markdown]
# <img src="./images/day17_6.PNG"></img>

# %%
#6
comp=df.groupby('company')

# %%
comp['company','price'].max()
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %% [markdown]
# <img src="./images/day17_7.PNG"></img>

# %%
# 7
comp['company','average-mileage'].mean()
# Out:
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %% [markdown]
# <img src="./images/day17_8.PNG"></img>

# %%
df.sort_values('price')
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 48     66         toyota    hatchback        95.7   158.7         ohc
# 36     49     mitsubishi    hatchback        93.7   157.3         ohc
# 28     37          mazda    hatchback        93.1   159.1         ohc
# 37     50     mitsubishi    hatchback        93.7   157.3         ohc
# 17     20          dodge    hatchback        93.7   157.3         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 49     67         toyota    hatchback        95.7   158.7         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 50     68         toyota    hatchback        95.7   158.7         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# ...

# %% [markdown]
# <img src="./images/day17_9.PNG"></img>

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
df1=pd.DataFrame(GermanCars)

# %%
df1
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
df2=pd.DataFrame(japaneseCars)

# %%
df2
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
#9
carsDf = pd.concat([df1, df2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
#         0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# <img src="./images/day17_10.PNG"></img>

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
df3=pd.DataFrame(Car_Price)
df4=pd.DataFrame(car_Horsepower)

# %%
pd.merge(df3,df4)
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
